# %% [markdown]
# ### 1.Getting Images

# %%
#!pip install opencv-python

# %%
#!python --version
# Out:
# Python 3.11.5

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\Face Mask Detector'

# %%
import cv2
import uuid
from datetime import datetime
import os

# Video Capture
cap = cv2.VideoCapture(0)

# Check if the video capture is successful
if not cap.isOpened():
    print("Error: Could not open video capture.")
    exit()

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

print("Is opened:", cap.isOpened())
print("Frame width:", width)
print("Frame height:", height)

output_directory = './Images/Mask/'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

while True:
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Resize the frame if needed
    # frame = cv2.resize(frame, (new_width, new_height))

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    image_name = f'{output_directory}{timestamp}_{str(uuid.uuid1())}.jpg'

    # Attempt to write the image
    success = cv2.imwrite(image_name, frame)
    
    if success:
        print(f"Image saved as '{image_name}'")
    else:
        print(f"Error: Failed to save image as '{image_name}'")

    cv2.imshow('frame', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Is opened: True
# Frame width: 640
# Frame height: 480
# Image saved as './Images/Mask/20240112_151112_b92a7608-b12e-11ee-9e91-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151112_b92eaee9-b12e-11ee-8615-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151112_b9335ee2-b12e-11ee-a1eb-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151112_b938fd1c-b12e-11ee-b838-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151112_b93d6fc9-b12e-11ee-9e2c-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151112_b9429cc1-b12e-11ee-8cc8-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151113_b947781d-b12e-11ee-a200-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151113_b94ce2e7-b12e-11ee-9083-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151113_b9509071-b12e-11ee-9105-f816540af29d.jpg'
# Image saved as './Images/Mask/20240112_151113_b959214e-b12e-11ee-8e03-f816540af29d.jpg'
# ...

# %% [raw]
# # Import opencv
# import cv2
# # Import uuid
# import uuid

# %% [raw]
# # Image Capture
# cap = cv2.VideoCapture(2)
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %% [raw]
# while True:
#     ret ,frame = cap.read()
#     image_name = './Image/Mask/{}.jpg'.format(str(uuid.uuid1()))
#     cv2.imwrite(imgname,frame)
#     cv2.imshow('frame',frame)
#
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# %% [raw]
# cap.release()
# cap.destroyAllWindows()

# %%
s = "a"

# %%
len(s)
# Out:
# 1
